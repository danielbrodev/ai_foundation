# %% [markdown]
# <a href="https://colab.research.google.com/github/danielbrodev/ai_foundation/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford",'Tesla','Ford','Ferrari'],
  'passings': [3, 7, 2,6,9,4]
}

df = pd.DataFrame(mydataset)

print(df)
# Out:
#       cars  passings
# 0      BMW         3
# 1    Volvo         7
# 2     Ford         2
# 3    Tesla         6
# 4     Ford         9
# 5  Ferrari         4

# %%
df.head() #default 5 rows
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2
# 3  Tesla         6
# 4   Ford         9

# %%
df.tail() # default 5 rows
# Out:
#       cars  passings
# 1    Volvo         7
# 2     Ford         2
# 3    Tesla         6
# 4     Ford         9
# 5  Ferrari         4

# %%
df.shape
# Out:
# (6, 2)

# %%
df.columns
# Out:
# Index(['cars', 'passings'], dtype='object')

# %%
df.dtypes
# Out:
# cars        object
# passings     int64
# dtype: object

# %%
df.describe() # numerical columns only
# Out:
#        passings
# count  6.000000
# mean   5.166667
# std    2.639444
# min    2.000000
# 25%    3.250000
# 50%    5.000000
# 75%    6.750000
# max    9.000000

# %%
df.iloc[2:]
# Out:
#       cars  passings
# 2     Ford         2
# 3    Tesla         6
# 4     Ford         9
# 5  Ferrari         4

# %%
df.loc[2:5,"cars"]
# Out:
# 2       Ford
# 3      Tesla
# 4       Ford
# 5    Ferrari
# Name: cars, dtype: object

# %%
print(df)
# Out:
#       cars  passings
# 0      BMW         3
# 1    Volvo         7
# 2     Ford         2
# 3    Tesla         6
# 4     Ford         9
# 5  Ferrari         4

# %%
df[df["cars"] == "Tesla"]
# Out:
#     cars  passings
# 3  Tesla         6

# %%
# df.mean(numeric_only=True)
# df["cars"].mean()

# %%
df.sum()
# Out:
# cars        BMWVolvoFordTeslaFordFerrari
# passings                              31
# dtype: object

# %%
df.min()
# Out:
# cars        BMW
# passings      2
# dtype: object

# %%
df.max()
# Out:
# cars        Volvo
# passings        9
# dtype: object

# %%
df.median(numeric_only=True)
# Out:
# passings    5.0
# dtype: float64

# %%
df.count()
# Out:
# cars        6
# passings    6
# dtype: int64

# %%
df.std(numeric_only=True)
# Out:
# passings    2.639444
# dtype: float64

# %%
data_with_missing = {
    "cars":["BMW","Volvo",None,"Tesla","Ferrari",None,"Ford"],
    "counts":[3,7,None,8,1,9,None]
}
df_missing = pd.DataFrame(data_with_missing)
print(df_missing)
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     None     NaN
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 5     None     9.0
# 6     Ford     NaN

# %%
df_missing.isnull().sum()
# Out:
# cars      2
# counts    2
# dtype: int64

# %%
df_missing.dropna(subset=['cars'])
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 6     Ford     NaN

# %%
df_missing.fillna(0)
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2        0     0.0
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 5        0     9.0
# 6     Ford     0.0

# %%
df = pd.read_excel("output.xlsx")

df.head(100)
# Out:
#     Unnamed: 0  PassengerId  Survived  Pclass  \
# 0            0            1         0       3
# 1            1            2         1       1
# 2            2            3         1       3
# 3            3            4         1       1
# 4            4            5         0       3
# ..         ...          ...       ...     ...
# 95          95           96         0       3
# 96          96           97         0       1
# 97          97           98         1       1
# 98          98           99         1       2
# 99          99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.to_excel("output.xlsx")

# %%
# Series => 1D
cars = pd.Series(["BMW","Tesla","Ferrari"])
print(cars)
# Out:
# 0        BMW
# 1      Tesla
# 2    Ferrari
# dtype: object

# %%
cars_series = data_with_missing['cars']
print(cars_series)
# Out:
# ['BMW', 'Volvo', None, 'Tesla', 'Ferrari', None, 'Ford']
